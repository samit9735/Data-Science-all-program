# %% [markdown]
# # Imdb Reviews

# %%
import requests
from bs4 import BeautifulSoup

# %%
#url = "http://www.imdb.com/chart/top"
url = "http://www.imdb.com/title/tt3521164/reviews?ref_=tt_urv"
resp = requests.get(url)
print(resp.status_code)
#print(resp.content)
soup = BeautifulSoup(resp.text,"html.parser")
#soup.prettify()
# Out:
# 200

# %%
reviews = soup.findAll("div", attrs={"class","text"})
print(type(reviews))
for i in range(len(reviews)):
    reviews[i] = reviews[i].text
    #print(reviews[i])
    #print("____________________________________")
# Out:
# <class 'bs4.element.ResultSet'>

# %%
# Creating a data frame 
import pandas as pd
movie_reviews = pd.DataFrame(columns = ["reviews"])
movie_reviews["reviews"] = reviews
movie_reviews
# Out:
#                                               reviews
# 0   Instant classic.Easily ranks among the best fr...
# 1   Wow, what a great great movie! The visuals in ...
# 2   2016 has been a particularly strong year for a...
# 3   Moana is a return to the classic Disney formul...
# 4   As an individual double majoring in Computer S...
# 5   Like most adults, I came to view this film as ...
# 6   Despite being a lifelong Disney fan, that is n...
# 7   I love everything about this movie. The colors...
# 8   Why this movie has 7.6? Y'all crazy, this is a...
# 9   Tell me if you've seen this movie:Princess wan...
# 10  From the opening lyrics to the final shot, Moa...
# 11  It is indeed very rare that I toss a top ratin...
# 12  I was expecting a standard, manufactured Disne...
# 13  Funny funny funny. I like the bit where the ch...
# 14  Moana is simplistic plot. Surround a young qua...
# 15  Henny's Movie Review: Moana (aka Vaiana)In thr...
# 16  Set on the Polynesian islands of the South Pac...
# 17  From the opening lyrics to the final shot, Moa...
# 18  I saw "Moana" tonight in the local movie theat...
# 19  So I watched Moana and boy, what a lazy movie ...
# 20  EDIT: Fixed a couple of grammatical errors, el...
# 21  Moana (or Vaiana in my country and many other ...
# 22  Maui was one of the best modern Disney movies,...
# 23  "Moana" is the latest full length animated fil...
# 24  Animation is good (except surely not all Polyn...

# %% [markdown]
# ## Top Movies

# %%
url = "http://www.imdb.com/chart/top"
#url = "http://www.imdb.com/title/tt3521164/reviews?ref_=tt_urv"
resp = requests.get(url)
#print(resp.status_code)
#print(resp.content)
soup = BeautifulSoup(resp.text,"html.parser")
#soup.prettify()

# %%
llist = soup.find("tbody", {"class":"lister-list"})
top_list=[]
trs = llist.findAll("tr")
for tr in trs:
    #print(tr.find("td",{"class":"titleColumn"}).text)
    item = tr.find("td",{"class":"titleColumn"}).text
    top_list.append(item.replace('\n',''))
top_list
# Out:
# ['      1.      The Shawshank Redemption(1994)',
#  '      2.      The Godfather(1972)',
#  '      3.      The Dark Knight(2008)',
#  '      4.      The Godfather: Part II(1974)',
#  '      5.      12 Angry Men(1957)',
#  "      6.      Schindler's List(1993)",
#  '      7.      The Lord of the Rings: The Return of the King(2003)',
#  '      8.      Pulp Fiction(1994)',
#  '      9.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '      10.      Il buono, il brutto, il cattivo(1966)',
#  '      11.      Forrest Gump(1994)',
#  '      12.      Fight Club(1999)',
#  '      13.      Inception(2010)',
#  '      14.      The Lord of the Rings: The Two Towers(2002)',
#  '      15.      The Empire Strikes Back(1980)',
#  '      16.      The Matrix(1999)',
#  '      17.      Goodfellas(1990)',
#  "      18.      One Flew Over the Cuckoo's Nest(1975)",
#  '      19.      Se7en(1995)',
#  '      20.      Shichinin no samurai(1954)',
#  "      21.      It's a Wonderful Life(1946)",
#  '      22.      The Silence of the Lambs(1991)',
#  '      23.      Cidade de Deus(2002)',
#  '      24.      Saving Private Ryan(1998)',
#  '      25.      La vita è bella(1997)',
#  '      26.      The Green Mile(1999)',
#  '      27.      Star Wars(1977)',
#  '      28.      Interstellar(2014)',
#  '      29.      Terminator 2: Judgment Day(1991)',
#  '      30.      Back to the Future(1985)',
#  '      31.      Sen to Chihiro no kamikakushi(2001)',
#  '      32.      Psycho(1960)',
#  '      33.      The Pianist(2002)',
#  '      34.      Léon(1994)',
#  '      35.      Gisaengchung(2019)',
#  '      36.      The Lion King(1994)',
#  '      37.      Gladiator(2000)',
#  '      38.      American History X(1998)',
#  '      39.      The Usual Suspects(1995)',
#  '      40.      The Departed(2006)',
#  '      41.      The Prestige(2006)',
#  '      42.      Casablanca(1942)',
#  '      43.      Whiplash(2014)',
#  '      44.      The Intouchables(2011)',
#  '      45.      Modern Times(1936)',
#  '      46.      Seppuku(1962)',
#  '      47.      Once Upon a Time in the West(1968)',
#  '      48.      Hotaru no haka(1988)',
#  '      49.      Rear Window(1954)',
#  '      50.      Alien(1979)',
#  '      51.      City Lights(1931)',
#  '      52.      Nuovo Cinema Paradiso(1988)',
#  '      53.      Memento(2000)',
#  '      54.      Apocalypse Now(1979)',
#  '      55.      Raiders of the Lost Ark(1981)',
#  '      56.      Django Unchained(2012)',
#  '      57.      WALL·E(2008)',
#  '      58.      The Lives of Others(2006)',
#  '      59.      Sunset Blvd.(1950)',
#  '      60.      Paths of Glory(1957)',
#  '      61.      The Shining(1980)',
#  '      62.      The Great Dictator(1940)',
#  '      63.      Witness for the Prosecution(1957)',
#  '      64.      Avengers: Infinity War(2018)',
#  '      65.      Aliens(1986)',
#  '      66.      American Beauty(1999)',
#  '      67.      Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb(1964)',
#  '      68.      The Dark Knight Rises(2012)',
#  '      69.      Everything Everywhere All at Once(2022)',
#  '      70.      Spider-Man: Into the Spider-Verse(2018)',
#  '      71.      Joker(2019)',
#  '      72.      Oldeuboi(2003)',
#  '      73.      Braveheart(1995)',
#  '      74.      Amadeus(1984)',
#  '      75.      Toy Story(1995)',
#  '      76.      Coco(2017)',
#  '      77.      Das Boot(1981)',
#  '      78.      Inglourious Basterds(2009)',
#  '      79.      Mononoke-hime(1997)',
#  '      80.      Once Upon a Time in America(1984)',
#  '      81.      Avengers: Endgame(2019)',
#  '      82.      Good Will Hunting(1997)',
#  '      83.      Requiem for a Dream(2000)',
#  '      84.      Toy Story 3(2010)',
#  "      85.      Singin' in the Rain(1952)",
#  '      86.      Kimi no na wa.(2016)',
#  '      87.      3 Idiots(2009)',
#  '      88.      Star Wars: Episode VI - Return of the Jedi(1983)',
#  '      89.      2001: A Space Odyssey(1968)',
#  '      90.      Reservoir Dogs(1992)',
#  '      91.      Eternal Sunshine of the Spotless Mind(2004)',
#  '      92.      Tengoku to jigoku(1963)',
#  '      93.      Capharnaüm(2018)',
#  '      94.      Citizen Kane(1941)',
#  '      95.      Lawrence of Arabia(1962)',
#  '      96.      Jagten(2012)',
#  '      97.      M - Eine Stadt sucht einen Mörder(1931)',
#  '      98.      North by Northwest(1959)',
#  '      99.      Vertigo(1958)',
#  "      100.      Le fabuleux destin d'Amélie Poulain(2001)",
#  '      101.      A Clockwork Orange(1971)',
#  '      102.      Idi i smotri(1985)',
#  '      103.      Full Metal Jacket(1987)',
#  '      104.      Double Indemnity(1944)',
#  '      105.      The Apartment(1960)',
#  '      106.      Scarface(1983)',
#  '      107.      Ikiru(1952)',
#  '      108.      To Kill a Mockingbird(1962)',
#  '      109.      The Sting(1973)',
#  '      110.      Taxi Driver(1976)',
#  '      111.      Spider-Man: No Way Home(2021)',
#  '      112.      L.A. Confidential(1997)',
#  '      113.      Hamilton(2020)',
#  '      114.      Up(2009)',
#  '      115.      Heat(1995)',
#  '      116.      Metropolis(1927)',
#  '      117.      Snatch(2000)',
#  '      118.      Jodaeiye Nader az Simin(2011)',
#  '      119.      Die Hard(1988)',
#  '      120.      Incendies(2010)',
#  '      121.      Indiana Jones and the Last Crusade(1989)',
#  '      122.      Ladri di biciclette(1948)',
#  '      123.      1917(2019)',
#  '      124.      Taare Zameen Par(2007)',
#  '      125.      Der Untergang(2004)',
#  '      126.      Per qualche dollaro in più(1965)',
#  '      127.      Batman Begins(2005)',
#  '      128.      Dangal(2016)',
#  '      129.      The Kid(1921)',
#  '      130.      Some Like It Hot(1959)',
#  '      131.      The Father(2020)',
#  '      132.      All About Eve(1950)',
#  '      133.      Green Book(2018)',
#  '      134.      The Wolf of Wall Street(2013)',
#  '      135.      Judgment at Nuremberg(1961)',
#  '      136.      Unforgiven(1992)',
#  "      137.      Pan's Labyrinth(2006)",
#  '      138.      Casino(1995)',
#  '      139.      Ran(1985)',
#  '      140.      There Will Be Blood(2007)',
#  '      141.      The Sixth Sense(1999)',
#  '      142.      A Beautiful Mind(2001)',
#  '      143.      Monty Python and the Holy Grail(1975)',
#  '      144.      The Truman Show(1998)',
#  '      145.      Yôjinbô(1961)',
#  '      146.      The Treasure of the Sierra Madre(1948)',
#  '      147.      Rashômon(1950)',
#  '      148.      The Great Escape(1963)',
#  '      149.      Shutter Island(2010)',
#  '      150.      Kill Bill: Vol. 1(2003)',
#  '      151.      Jurassic Park(1993)',
#  '      152.      No Country for Old Men(2007)',
#  '      153.      The Elephant Man(1980)',
#  '      154.      Finding Nemo(2003)',
#  '      155.      Raging Bull(1980)',
#  '      156.      Chinatown(1974)',
#  '      157.      Gone with the Wind(1939)',
#  '      158.      V for Vendetta(2005)',
#  '      159.      Inside Out(2015)',
#  '      160.      Lock, Stock and Two Smoking Barrels(1998)',
#  '      161.      The Thing(1982)',
#  '      162.      Dial M for Murder(1954)',
#  '      163.      El secreto de sus ojos(2009)',
#  '      164.      The Bridge on the River Kwai(1957)',
#  '      165.      Hauru no ugoku shiro(2004)',
#  '      166.      Three Billboards Outside Ebbing, Missouri(2017)',
#  '      167.      Trainspotting(1996)',
#  '      168.      Gran Torino(2008)',
#  '      169.      Warrior(2011)',
#  '      170.      Fargo(1996)',
#  '      171.      Tonari no Totoro(1988)',
#  '      172.      Prisoners(2013)',
#  '      173.      Million Dollar Baby(2004)',
#  '      174.      The Gold Rush(1925)',
#  '      175.      Blade Runner(1982)',
#  '      176.      Catch Me If You Can(2002)',
#  '      177.      On the Waterfront(1954)',
#  '      178.      The Third Man(1949)',
#  '      179.      Bacheha-Ye aseman(1997)',
#  '      180.      Ben-Hur(1959)',
#  '      181.      The General(1926)',
#  '      182.      12 Years a Slave(2013)',
#  '      183.      Gone Girl(2014)',
#  '      184.      Smultronstället(1957)',
#  '      185.      The Deer Hunter(1978)',
#  '      186.      Before Sunrise(1995)',
#  '      187.      Harry Potter and the Deathly Hallows: Part 2(2011)',
#  '      188.      In the Name of the Father(1993)',
#  '      189.      The Grand Budapest Hotel(2014)',
#  '      190.      Mr. Smith Goes to Washington(1939)',
#  '      191.      Le salaire de la peur(1953)',
#  '      192.      Sherlock Jr.(1924)',
#  '      193.      Barry Lyndon(1975)',
#  '      194.      Room(2015)',
#  '      195.      Salinui chueok(2003)',
#  '      196.      Hacksaw Ridge(2016)',
#  '      197.      Det sjunde inseglet(1957)',
#  '      198.      Klaus(2019)',
#  '      199.      Relatos salvajes(2014)',
#  '      200.      The Big Lebowski(1998)',
#  '      201.      How to Train Your Dragon(2010)',
#  '      202.      Mad Max: Fury Road(2015)',
#  '      203.      Mary and Max.(2009)',
#  '      204.      Monsters, Inc.(2001)',
#  '      205.      Jaws(1975)',
#  "      206.      La passion de Jeanne d'Arc(1928)",
#  '      207.      Pather Panchali(1955)',
#  '      208.      Hotel Rwanda(2004)',
#  '      209.      Tôkyô monogatari(1953)',
#  '      210.      Dead Poets Society(1989)',
#  '      211.      Platoon(1986)',
#  '      212.      Rocky(1976)',
#  '      213.      Ford v Ferrari(2019)',
#  '      214.      Stand by Me(1986)',
#  '      215.      The Terminator(1984)',
#  '      216.      Rush(2013)',
#  '      217.      Spotlight(2015)',
#  '      218.      Into the Wild(2007)',
#  '      219.      Network(1976)',
#  '      220.      The Wizard of Oz(1939)',
#  '      221.      Logan(2017)',
#  '      222.      Groundhog Day(1993)',
#  '      223.      Ratatouille(2007)',
#  '      224.      The Exorcist(1973)',
#  '      225.      Before Sunset(2004)',
#  '      226.      The Best Years of Our Lives(1946)',
#  '      227.      The Incredibles(2004)',
#  '      228.      To Be or Not to Be(1942)',
#  '      229.      La battaglia di Algeri(1966)',
#  '      230.      Rebecca(1940)',
#  '      231.      The Grapes of Wrath(1940)',
#  "      232.      Hachi: A Dog's Tale(2009)",
#  '      233.      Cool Hand Luke(1967)',
#  '      234.      Amores perros(2000)',
#  '      235.      Pirates of the Caribbean: The Curse of the Black Pearl(2003)',
#  '      236.      Dersu Uzala(1975)',
#  '      237.      Les quatre cents coups(1959)',
#  '      238.      Persona(1966)',
#  '      239.      La haine(1995)',
#  '      240.      Babam ve Oglum(2005)',
#  '      241.      Life of Brian(1979)',
#  '      242.      The Sound of Music(1965)',
#  '      243.      It Happened One Night(1934)',
#  '      244.      Ah-ga-ssi(2016)',
#  '      245.      Aladdin(1992)',
#  '      246.      Gandhi(1982)',
#  '      247.      The Help(2011)',
#  '      248.      Beauty and the Beast(1991)',
#  '      249.      Dances with Wolves(1990)',
#  '      250.      Jai Bhim(2021)']

# %% [markdown]
# ## Amazon Kindle Review

# %%
url = "https://www.amazon.in/All-New-Kindle-reader-Glare-Free-Touchscreen/product-reviews/B0186FF45G/ref=cm_cr_getr_d_paging_btm_3?showViewpoints=1&pageNumber="
#url="https://www.amazon.in/Apple-MacBook-Air-13-3-inch-Integrated/product-reviews/B073Q5R6VR/ref=cm_cr_arp_d_paging_btm_2?showViewpoints=1&pageNumber="+str(i)
response = requests.get(url)
#print(response.content)
# creating soup object to iterate over the extracted content 
soup = BeautifulSoup(response.content,"html")
#print(soup)

reviews = soup.findAll("span",attrs={"class","review-text-content"})
for i in range(len(reviews)):    
    reviews[i] = reviews[i].text

# %%
# Creating a data frame 
import pandas as pd
kindle_reviews = pd.DataFrame(columns = ["reviews"])
kindle_reviews["reviews"] = reviews
kindle_reviews
# Out:
#                                              reviews
# 0  \nI'm writing this after using this kindle for...
# 1  \nAre you considering buying a Kindle? Here's ...
# 2  \nHave been using it for months and it is simp...
# 3  \nAt first, this ebook reader will be felt lik...
# 4  \nI was in a dilemma of whether it'll be at pa...
# 5  \nBattery did not charge after 4-5 hours. Wors...
# 6  \nOriginally ordered a new Kindle, it worked f...
# 7  \nThis is a review for both Kindle device & Ki...
# 8  \nKindle is pathetic.  The first ever Kindle I...
# 9  \nKindle format books are really fantastic on ...
